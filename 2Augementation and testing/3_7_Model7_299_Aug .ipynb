# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.style.use('classic')

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.layers import Activation, Dropout, Flatten, Dense

# %%
import os
import cv2
from PIL import Image
import numpy as np

# %%
image_directory = '299aug-nor-macular/'
SIZE = 125
dataset = []  #Many ways to handle data, you can use pandas. Here, we are using a list format.  
label = []  #Place holders to define add labels. We will add 0 to all parasitized images and 1 to uninfected.

# %%
macular_degeneration_images = os.listdir(image_directory + 'macular-degeneration/')
for i, image_name in enumerate(macular_degeneration_images):    #Remember enumerate method adds a counter and returns the enumerate object
    
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(image_directory + 'macular-degeneration/' + image_name)
        image = Image.fromarray(image, 'RGB')
        image = image.resize((SIZE, SIZE))
        dataset.append(np.array(image))
        label.append(0)

#Iterate through all images in Uninfected folder, resize to 64 x 64
#Then save into the same numpy array 'dataset' but with label 1

# %%
normal_images = os.listdir(image_directory + 'normal/')
for i, image_name in enumerate(normal_images):
    if (image_name.split('.')[1] == 'jpg'):
        image = cv2.imread(image_directory + 'normal/' + image_name)
        image = Image.fromarray(image, 'RGB')
        image = image.resize((SIZE, SIZE))
        dataset.append(np.array(image))
        label.append(1)

dataset = np.array(dataset)
label = np.array(label)

# %%
from sklearn.model_selection import train_test_split
#from keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset, label, test_size = 0.20, random_state = 0)

# %%
#Without scaling (normalize) the training may not converge. 
#Normalization is a rescaling of the data from the original range 
#so that all values are within the range of 0 and 1.
from tensorflow.keras.utils import normalize
X_train = normalize(X_train, axis=1)
X_test = normalize(X_test, axis=1)

#Do not do one-hot encoding as it generates a shape of (num, 2)
#But the network expects an input of (num, 1) for the last layer for binary classification
#y_train = to_categorical(y_train)
#y_test = to_categorical(y_test)

# %%
# 2 conv and pool layers. with some normalization and drops in between.

INPUT_SHAPE = (SIZE, SIZE, 3)   #change to (SIZE, SIZE, 3)


model = Sequential()
model.add(Conv2D(128, (3, 3), input_shape=INPUT_SHAPE))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3), kernel_initializer = 'he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))


model.add(Conv2D(128, (3, 3), kernel_initializer = 'he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))


model.add(Conv2D(128, (3, 3), kernel_initializer = 'he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3), kernel_initializer = 'he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))


model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.3))

model.add(Dense(1))
model.add(Activation('sigmoid'))  
#Do not use softmax for binary classification
#Softmax is useful for mutually exclusive classes, either cat or dog but not both.
#Also, softmax outputs all add to 1. So good for multi class problems where each
#class is given a probability and all add to 1. Highest one wins.

# %%
#Sigmoid outputs probability. Can be used for non-mutually exclusive problems.
#But, also good for binary mutually exclusive (cat or not cat). 

model.compile(loss='binary_crossentropy',
              optimizer='adam',             #also try adam
              metrics=['accuracy'])

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 123, 123, 128)     3584
# _________________________________________________________________
# activation (Activation)      (None, 123, 123, 128)     0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 61, 61, 128)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 61, 61, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 59, 59, 128)       147584
# _________________________________________________________________
# activation_1 (Activation)    (None, 59, 59, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 29, 29, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 29, 29, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 27, 27, 128)       147584
# _________________________________________________________________
# activation_2 (Activation)    (None, 27, 27, 128)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 11, 11, 128)       147584
# _________________________________________________________________
# activation_3 (Activation)    (None, 11, 11, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 5, 5, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# activation_4 (Activation)    (None, 3, 3, 128)         0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               33024
# _________________________________________________________________
# activation_5 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# _________________________________________________________________
# activation_6 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 627,201
# Trainable params: 627,201
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(X_train, 
                         y_train, 
                         batch_size = 32, 
                         verbose = 1, 
                         epochs = 50,      
                         validation_data=(X_test,y_test),
                         shuffle = False
                     )
# Out:
# Epoch 1/50
# 200/200 [==============================] - 222s 1s/step - loss: 0.6145 - accuracy: 0.6333 - val_loss: 0.5256 - val_accuracy: 0.7350
# Epoch 2/50
# 200/200 [==============================] - 228s 1s/step - loss: 0.4895 - accuracy: 0.7636 - val_loss: 0.4567 - val_accuracy: 0.7837
# Epoch 3/50
# 200/200 [==============================] - 215s 1s/step - loss: 0.4517 - accuracy: 0.7869 - val_loss: 0.4703 - val_accuracy: 0.7800
# Epoch 4/50
# 200/200 [==============================] - 221s 1s/step - loss: 0.4219 - accuracy: 0.8087 - val_loss: 0.4251 - val_accuracy: 0.8188
# Epoch 5/50
# 200/200 [==============================] - 217s 1s/step - loss: 0.3716 - accuracy: 0.8402 - val_loss: 0.3495 - val_accuracy: 0.8587
# Epoch 6/50
# 200/200 [==============================] - 216s 1s/step - loss: 0.3425 - accuracy: 0.8559 - val_loss: 0.3616 - val_accuracy: 0.8519
# Epoch 7/50
# 200/200 [==============================] - 218s 1s/step - loss: 0.3208 - accuracy: 0.8647 - val_loss: 0.3094 - val_accuracy: 0.8750
# Epoch 8/50
# 200/200 [==============================] - 215s 1s/step - loss: 0.3137 - accuracy: 0.8703 - val_loss: 0.3156 - val_accuracy: 0.8756
# Epoch 9/50
# 200/200 [==============================] - 214s 1s/step - loss: 0.3098 - accuracy: 0.8714 - val_loss: 0.3021 - val_accuracy: 0.8788
# Epoch 10/50
# 200/200 [==============================] - 219s 1s/step - loss: 0.2974 - accuracy: 0.8773 - val_loss: 0.3570 - val_accuracy: 0.8512
# Epoch 11/50
# 200/200 [==============================] - 215s 1s/step - loss: 0.2861 - accuracy: 0.8814 - val_loss: 0.2897 - val_accuracy: 0.8788
# Epoch 12/50
# 200/200 [==============================] - 215s 1s/step - loss: 0.2795 - accuracy: 0.8828 - val_loss: 0.2832 - val_accuracy: 0.8838
# Epoch 13/50
# 200/200 [==============================] - 223s 1s/step - loss: 0.2765 - accuracy: 0.8823 - val_loss: 0.2840 - val_accuracy: 0.8813
# Epoch 14/50
# 200/200 [==============================] - 215s 1s/step - loss: 0.2672 - accuracy: 0.8898 - val_loss: 0.2753 - val_accuracy: 0.8869
# Epoch 15/50
# 200/200 [==============================] - 217s 1s/step - loss: 0.2573 - accuracy: 0.8934 - val_loss: 0.2701 - val_accuracy: 0.8881
# Epoch 16/50
# 200/200 [==============================] - 217s 1s/step - loss: 0.2600 - accuracy: 0.8952 - val_loss: 0.2799 - val_accuracy: 0.8850
# Epoch 17/50
# 200/200 [==============================] - 216s 1s/step - loss: 0.2453 - accuracy: 0.8995 - val_loss: 0.2746 - val_accuracy: 0.8794
# Epoch 18/50
# 200/200 [==============================] - 219s 1s/step - loss: 0.2436 - accuracy: 0.9008 - val_loss: 0.2724 - val_accuracy: 0.8731
# Epoch 19/50
# 200/200 [==============================] - 225s 1s/step - loss: 0.2418 - accuracy: 0.9005 - val_loss: 0.2573 - val_accuracy: 0.8925
# Epoch 20/50
# 200/200 [==============================] - 225s 1s/step - loss: 0.2346 - accuracy: 0.9050 - val_loss: 0.2936 - val_accuracy: 0.8700
# Epoch 21/50
# 200/200 [==============================] - 223s 1s/step - loss: 0.2280 - accuracy: 0.9067 - val_loss: 0.3680 - val_accuracy: 0.8388
# Epoch 22/50
# 200/200 [==============================] - 223s 1s/step - loss: 0.2329 - accuracy: 0.9058 - val_loss: 0.2576 - val_accuracy: 0.8900
# Epoch 23/50
# 200/200 [==============================] - 216s 1s/step - loss: 0.2221 - accuracy: 0.9067 - val_loss: 0.2516 - val_accuracy: 0.8950
# Epoch 24/50
# 200/200 [==============================] - 217s 1s/step - loss: 0.2276 - accuracy: 0.9067 - val_loss: 0.2566 - val_accuracy: 0.8906
# Epoch 25/50
# 200/200 [==============================] - 215s 1s/step - loss: 0.2130 - accuracy: 0.9125 - val_loss: 0.2528 - val_accuracy: 0.8869
# Epoch 26/50
# 200/200 [==============================] - 217s 1s/step - loss: 0.2121 - accuracy: 0.9128 - val_loss: 0.2527 - val_accuracy: 0.8944
# Epoch 27/50
# 200/200 [==============================] - 217s 1s/step - loss: 0.2152 - accuracy: 0.9123 - val_loss: 0.2434 - val_accuracy: 0.8963
# Epoch 28/50
# 200/200 [==============================] - 215s 1s/step - loss: 0.2094 - accuracy: 0.9144 - val_loss: 0.2412 - val_accuracy: 0.8950
# Epoch 29/50
# 200/200 [==============================] - 224s 1s/step - loss: 0.2015 - accuracy: 0.9164 - val_loss: 0.2529 - val_accuracy: 0.8894
# Epoch 30/50
# 200/200 [==============================] - 215s 1s/step - loss: 0.1901 - accuracy: 0.9212 - val_loss: 0.2438 - val_accuracy: 0.8994
# Epoch 31/50
# 200/200 [==============================] - 216s 1s/step - loss: 0.1936 - accuracy: 0.9206 - val_loss: 0.2526 - val_accuracy: 0.8906
# Epoch 32/50
# 200/200 [==============================] - 218s 1s/step - loss: 0.1880 - accuracy: 0.9234 - val_loss: 0.2529 - val_accuracy: 0.8950
# Epoch 33/50
# 200/200 [==============================] - 215s 1s/step - loss: 0.1837 - accuracy: 0.9223 - val_loss: 0.2643 - val_accuracy: 0.8850
# Epoch 34/50
# 200/200 [==============================] - 215s 1s/step - loss: 0.1858 - accuracy: 0.9244 - val_loss: 0.2472 - val_accuracy: 0.8919
# Epoch 35/50
# 200/200 [==============================] - 219s 1s/step - loss: 0.1855 - accuracy: 0.9227 - val_loss: 0.2635 - val_accuracy: 0.8869
# Epoch 36/50
# 200/200 [==============================] - 215s 1s/step - loss: 0.1792 - accuracy: 0.9311 - val_loss: 0.2420 - val_accuracy: 0.9019
# Epoch 37/50
# 200/200 [==============================] - 221s 1s/step - loss: 0.1744 - accuracy: 0.9292 - val_loss: 0.2754 - val_accuracy: 0.8775
# Epoch 38/50
# 200/200 [==============================] - 221s 1s/step - loss: 0.1762 - accuracy: 0.9264 - val_loss: 0.2286 - val_accuracy: 0.9094
# Epoch 39/50
# 200/200 [==============================] - 231s 1s/step - loss: 0.1710 - accuracy: 0.9327 - val_loss: 0.2354 - val_accuracy: 0.9000
# Epoch 40/50
# 200/200 [==============================] - 218s 1s/step - loss: 0.1652 - accuracy: 0.9292 - val_loss: 0.2993 - val_accuracy: 0.8775
# Epoch 41/50
# 200/200 [==============================] - 217s 1s/step - loss: 0.1660 - accuracy: 0.9303 - val_loss: 0.2836 - val_accuracy: 0.8819
# Epoch 42/50
# 200/200 [==============================] - 217s 1s/step - loss: 0.1641 - accuracy: 0.9320 - val_loss: 0.2437 - val_accuracy: 0.8950
# Epoch 43/50
# 200/200 [==============================] - 220s 1s/step - loss: 0.1576 - accuracy: 0.9337 - val_loss: 0.2377 - val_accuracy: 0.9056
# Epoch 44/50
# 200/200 [==============================] - 216s 1s/step - loss: 0.1583 - accuracy: 0.9356 - val_loss: 0.2516 - val_accuracy: 0.9025
# Epoch 45/50
# 200/200 [==============================] - 216s 1s/step - loss: 0.1706 - accuracy: 0.9328 - val_loss: 0.2388 - val_accuracy: 0.9025
# Epoch 46/50
# 200/200 [==============================] - 222s 1s/step - loss: 0.1558 - accuracy: 0.9353 - val_loss: 0.3406 - val_accuracy: 0.8600
# Epoch 47/50
# 200/200 [==============================] - 214s 1s/step - loss: 0.1520 - accuracy: 0.9366 - val_loss: 0.2562 - val_accuracy: 0.8881
# Epoch 48/50
# 200/200 [==============================] - 214s 1s/step - loss: 0.1392 - accuracy: 0.9436 - val_loss: 0.2564 - val_accuracy: 0.9038
# Epoch 49/50
# 200/200 [==============================] - 214s 1s/step - loss: 0.1463 - accuracy: 0.9403 - val_loss: 0.2762 - val_accuracy: 0.8894
# Epoch 50/50
# 200/200 [==============================] - 212s 1s/step - loss: 0.1363 - accuracy: 0.9450 - val_loss: 0.2921 - val_accuracy: 0.8844

# %%
model.save('model2_50epochs128x5_acc9450_val9038.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy' ]
plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
# Function add a legend  
plt.legend(bbox_to_anchor =(0.75, -0.15), ncol = 10)
plt.show()

# %%
n=800  #Select the index of image to be loaded for testing
img = X_test[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
print("The prediction for this image is: ", model.predict(input_img))
print("The actual label for this image is: ", y_test[n])
# Out:
# The prediction for this image is:  [[1.]]
# The actual label for this image is:  1

# %%
#We can load the trained model, so we don't have to train again for 300 epochs!
from keras.models import load_model
# load model
model = load_model('model2_50epochs128x5_acc9450_val9038.h5')

#For 300 epochs, giving 82.5% accuracy

_, acc = model.evaluate(X_test, y_test)
print("Accuracy = ", (acc * 100.0), "%")
# Out:
# 50/50 [==============================] - 11s 208ms/step - loss: 0.2921 - accuracy: 0.8844
# Accuracy =  88.43749761581421 %

# %%
#How do we know how it is doing for parasitized vs uninfected? 
################################################################

#Confusion matrix
#We compare labels and plot them based on correct or wrong predictions.
#Since sigmoid outputs probabilities we need to apply threshold to convert to label.

mythreshold=0.908
from sklearn.metrics import confusion_matrix

y_pred = (model.predict(X_test)>= mythreshold).astype(int)
cm=confusion_matrix(y_test, y_pred)  
print(cm)
# Out:
# [[776  34]
#  [122 668]]

# %%
#Check the confusion matrix for various thresholds. Which one is good?
#Need to balance positive, negative, false positive and false negative. 
#ROC can help identify the right threshold.
##################################################################
"""
Receiver Operating Characteristic (ROC) Curve is a plot that helps us 
visualize the performance of a binary classifier when the threshold is varied. 
"""
#ROC
from sklearn.metrics import roc_curve
y_preds = model.predict(X_test).ravel()

fpr, tpr, thresholds = roc_curve(y_test, y_preds)
plt.figure(1)
plt.plot([0, 1], [0, 1], 'y--')
plt.plot(fpr, tpr, marker='.')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.show()

# %%
"""
#One way to find the best threshold once we calculate the true positive 
and false positive rates is ...
The optimal cut off point would be where “true positive rate” is high 
and the “false positive rate” is low. 
Based on this logic let us find the threshold where tpr-(1-fpr) is zero (or close to 0)
"""
import pandas as pd
i = np.arange(len(tpr)) 
roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'thresholds' : pd.Series(thresholds, index=i)})
ideal_roc_thresh = roc.iloc[(roc.tf-0).abs().argsort()[:1]]  #Locate the point where the value is close to 0
print("Ideal threshold is: ", ideal_roc_thresh['thresholds']) 

#Now use this threshold value in the confusion matrix to visualize the balance
#between tp, fp, fp, and fn
# Out:
# Ideal threshold is:  103    0.694851
# Name: thresholds, dtype: float32

# %%
#AUC
#Area under the curve (AUC) for ROC plot can be used to understand hpw well a classifier 
#is performing. 
#% chance that the model can distinguish between positive and negative classes.

from sklearn.metrics import auc
auc_value = auc(fpr, tpr)
print("Area under curve, AUC = ", auc_value)
# Out:
# Area under curve, AUC =  0.9665588373183309

# %%
#We can load the trained model, so we don't have to train again for 300 epochs!
from keras.models import load_model
# load model
model = load_model('model2_50epochs128x5_acc9450_val9038.h5')

#For 300 epochs, giving 82.5% accuracy

_, acc = model.evaluate(X_test, y_test)
print("Accuracy = ", (acc * 100.0), "%")
# Out:
# 50/50 [==============================] - 11s 209ms/step - loss: 0.2921 - accuracy: 0.8844
# Accuracy =  88.43749761581421 %
